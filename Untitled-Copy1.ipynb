# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import posixpath
from sklearn.preprocessing import StandardScaler
import wfdb

# %% [markdown]
# # finding metrics fora single record

# %%
record = wfdb.rdrecord('european-st-t-database/e0103') 
wfdb.plot_wfdb(record=record, title='Record e0103 from European st-t') 
display(record.__dict__)
# Out:
# {'record_name': 'e0103',
#  'n_sig': 2,
#  'fs': 250,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 1800000,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['Age: 62  Sex: M',
#   'Mixed angina',
#   '1-vessel disease (RCA)',
#   'Medications: nitrates, diltiazem',
#   'Recorder type: ICR 7200'],
#  'sig_name': ['V4', 'MLIII'],
#  'p_signal': array([[0.455, 3.755],
#         [0.46 , 3.78 ],
#         [0.45 , 3.765],
#         ...,
#         [0.535, 3.91 ],
#         [0.54 , 3.87 ],
#         [0.53 , 3.865]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['e0103.dat', 'e0103.dat'],
#  'fmt': ['212', '212'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [200.0, 200.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [12, 12],
#  'adc_zero': [0, 0],
#  'init_value': [91, 751],
#  'checksum': [56457, 48959],
#  'block_size': [0, 0]}

# %%
import numpy as np
arr1=np.array(record.p_signal[:])
x, y = arr1.T
np.where(x == max(x))[0][0]
max(x)
x=np.array([y for y in x])
x=x.reshape(-1, 1)

# %%
print(x[:50])
# Out:
# [[0.455]
#  [0.46 ]
#  [0.45 ]
#  [0.425]
#  [0.435]
#  [0.455]
#  [0.49 ]
#  [0.5  ]
#  [0.485]
#  [0.5  ]
#  [0.495]
#  [0.5  ]
#  [0.5  ]
#  [0.515]
#  [0.53 ]
#  [0.56 ]
#  [0.57 ]
#  [0.56 ]
#  [0.535]
#  [0.535]
#  [0.535]
#  [0.525]
#  [0.51 ]
#  [0.5  ]
#  [0.5  ]
#  [0.49 ]
#  [0.485]
#  [0.465]
#  [0.46 ]
#  [0.45 ]
#  [0.445]
#  [0.44 ]
#  [0.435]
#  [0.44 ]
#  [0.445]
#  [0.475]
#  [0.495]
#  [0.5  ]
#  [0.5  ]
#  [0.48 ]
#  [0.45 ]
#  [0.43 ]
#  [0.43 ]
#  [0.445]
#  [0.495]
#  [0.63 ]
#  [0.88 ]
#  [1.29 ]
#  [1.77 ]
#  [2.19 ]]

# %% [markdown]
# scaler=StandardScaler((0,1))
# scaler.fit(x)
# arr2=scaler.transform(x)

# %%
from matplotlib import pyplot as plt
ts=[y for y in range(1800000)]
plt.scatter(ts,x)
plt.show()

# %%
np.nanmean(x)
# Out:
# 0.5674073138888887

# %%
np.nanstd(x)
# Out:
# 0.29070102108400797

# %%
r_point_array = []
start_index = 0

while (start_index < 1800000):
    if start_index == 0:
        ts=np.array([u+1 for u in range(200)])
        sample=x[:200]
        r_point_y=max(sample)
        point=np.where(sample == max(sample))[0][0]
        r_point_x=ts[point]
        #print(r_point_y)
        r_point_array+=[r_point_x]
        start_index=int(r_point_x)+40
    else:
        ts=np.array([u+1 for u in range(200)])
        
        sample=sample.reshape(1,-1)[0]
        next_i=0
        #print(sample)
        if (start_index+next_i)<1800000:
            while (start_index+next_i)<1800000 and x[start_index+next_i]<0.24:
                next_i+=1
            while (start_index+next_i)<1800000 and x[next_i]<x[next_i+1]:
                next_i+=1
            r_point_array+=[start_index+next_i] 
        # next we find the slope made by the line connecting to the s point
        start_index=start_index+next_i+40
print(r_point_array)
# Out:
# [51, 92, 133, 174, 215, 256, 297, 338, 379, 420, 461, 502, 543, 584, 625, 666, 707, 748, 789, 830, 871, 912, 953, 994, 1035, 1076, 1117, 1158, 1199, 1240, 1281, 1322, 1363, 1404, 1445, 1486, 1527, 1568, 1609, 1650, 1691, 1732, 1773, 1814, 1855, 1896, 1937, 1978, 2019, 2060, 2101, 2142, 2183, 2224, 2265, 2306, 2347, 2388, 2429, 2470, 2511, 2552, 2593, 2634, 2675, 2716, 2757, 2798, 2839, 2880, 2921, 2962, 3003, 3044, 3085, 3126, 3167, 3208, 3249, 3290, 3331, 3372, 3413, 3454, 3495, 3536, 3577, 3618, 3659, 3700, 3741, 3782, 3823, 3864, 3905, 3946, 3987, 4028, 4069, 4110, 4151, 4192, 4233, 4274, 4315, 4356, 4397, 4438, 4479, 4520, 4561, 4602, 4643, 4684, 4725, 4766, 4807, 4848, 4889, 4930, 4971, 5012, 5053, 5094, 5135, 5176, 5217, 5258, 5299, 5340, 5381, 5422, 5463, 5504, 5545, 5586, 5627, 5668, 5709, 5750, 5791, 5832, 5873, 5914, 5955, 5996, 6037, 6078, 6119, 6160, 6201, 6242, 6283, 6324, 6365, 6406, 6447, 6488, 6529, 6570, 6611, 6652, 6693, 6734, 6775, 6816, 6857, 6898, 6939, 6980, 7021, 7062, 7103, 7144, 7185, 7226, 7267, 7308, 7349, 7390, 7431, 7472, 7513, 7554, 7595, 7636, 7677, 7718, 7759, 7800, 7841, 7882, 7923, 7964, 8005, 8046, 8087, 8128, 8169, 8210, 8251, 8292, 8333, 8374, 8415, 8456, 8497, 8538, 8579, 8620, 8661, 8702, 8743, 8784, 8825, 8866, 8907, 8948, 8989, 9030, 9071, 9112, 9153, 9194, 9235, 9276, 9317, 9358, 9399, 9440, 9481, 9522, 9563, 9604, 9645, 9686, 9727, 9768, 9809, 9850, 9891, 9932, 9973, 10014, 10055, 10096, 10137, 10178, 10219, 10260, 10301, 10342, 10383, 10424, 10465, 10506, 10547, 10588, 10629, 10670, 10711, 10752, 10793, 10834, 10875, 10916, 10957, 10998, 11039, 11080, 11121, 11162, 11203, 11244, 11285, 11326, 11367, 11408, 11449, 11490, 11531, 11572, 11613, 11654, 11695, 11736, 11777, 11818, 11859, 11900, 11941, 11982,
600125402, -0.04068193767022876, nan, 0.0, -1.1457628381751022, 0.011936620559197308, -0.04177816515735344, -0.21644010741383113, -0.423696935350506, nan, -0.00596831034437173, -0.06029204460253368, -1.3186984352749676, -0.2133972126668766, nan, nan, -0.2506666527441439, -0.10207006016420905, -0.14092506410744932, -0.12821031234881275, -0.429707305434448, nan, -0.5669703873391256, -0.059683082072695015, -0.8648572880962035, -0.09476212637110848, -0.12448183572413996, nan, nan, nan, -1.6885164525240555, nan, -0.24104236324583894, -0.29243035165509923, nan, -0.25663496114569284, nan, -0.2446988867623361, -0.18547345348937938, -0.28289273938290194, nan, 0.00596831034437173, -0.3222863678100225, -0.4833002854028905, nan, -0.1369055584180785, nan, -0.5371288401505581, -0.023873240082224356, -0.06601676209635343, -0.6087304847771406, -0.19597947637592483, 2.0132011781777805, 0.047381072924252976, nan, -0.03008514909254245, -1.4378246022260157, -0.04786826946346423, -0.08233830092612493, nan, nan, nan, -0.2685715797620958, nan, -0.2936608173779973, -0.23672327375726354, -0.00596831034437173, nan, -0.2864765102770832, 0.0716196870894521, -0.299628898479682, -0.4942502376918583, nan, nan, -0.06017025473357762, -2.361888321706658, -0.08928100339602452, -0.059074087162798605, 0.0031668358033982713, 0.3628447417725056, -0.018270333740076694, -0.029841549131390366, 0.0025578353081243677, -0.2026782404244898, 2.212262214489357, 0.07064529460140534, -0.24469834511972977, nan, -0.029719748175523364, -0.018635733258349774, -0.1249689844861166, nan, -0.16711198427745444, nan, -0.1790486038004815, nan, -0.28135981085142703, -0.328227003154 ...

# %%
print(np.nanmean(qrs_angle_list),np.nanstd(qrs_angle_list))
# Out:
# -0.2650395187303037 0.7308681851298603

# %%
qrs_area_list=[]

import math
for r_point_x in r_point_array:
    r_point_y=x[r_point_x][0]
    # next we find the slope made by the line connecting to the s point
    d=50
    if r_point_x+50>1800000:
        d=1800000-r_point_x
    for j in range(r_point_x,r_point_x+d-1):
        if x[j]<x[j+1] and x[j]<0:
            break
    for k in range(r_point_x,r_point_x-50,-1):
        if x[k-1]>x[k] and x[j]<0.5:
            break
    q_point_y=x[k][0]
    q_point_x=k
    s_point_y=x[j][0]
    s_point_x=j
    #print(q_point_x,q_point_y,r_point_x,r_point_y,s_point_x,s_point_y)
    area_tri=0.5*((r_point_x*(q_point_y-s_point_y))+(q_point_x*(s_point_y-r_point_y))+(s_point_x*(r_point_y-q_point_y)))
    if abs(area_tri)>30:
        qrs_area_list+=[abs(area_tri)]
print(qrs_area_list)
# Out:
# [87.3875, 90.67250000000007, 44.60499999999999, 32.572500000000105, 78.41249999999991, 80.35249999999996, 92.11750000000029, 44.604999999999535, 85.44499999999971, 30.512499999999818, 35.94500000000062, 48.02499999999858, 39.05500000000029, 73.31750000000011, 61.06999999999971, 57.92750000000069, 78.29500000000007, 95.02750000000015, 53.69250000000011, 89.81750000000102, 90.17250000000058, 39.62249999999949, 41.53749999999869, 38.60250000000008, 61.67749999999978, 32.
# %%
print(np.nanmean(qrs_area_list),np.nanstd(qrs_area_list))
# Out:
# 57.70856488853667 22.618386879712748

# %% [markdown]
# # finding metrics for multiple records

# %%
# function to read multiple records
import os
def rec_list(dir_name):
    file_rec = os.listdir(dir_name)
    file_list=[]
    for f in file_rec:
        if f.endswith('.atr'):
            str_f_name=f.split('.')[0]
            file_list+=[dir_name+'/'+str_f_name]
    return file_list
#dir_name= 'european-st-t-database'

# %%
# function to read records
def read_rec(f_name):
    record = wfdb.rdrecord(f_name)
    print(record.sig_name)
    if 'V4' in record.sig_name:
        #wfdb.plot_wfdb(record=record, title=f_name)
        #print("Reading "+f_name)
        #display(record.__dict__)
        return record
    else:
        return {}

# %%
# function to scale the data availble
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
def scale_input_data(record):
    arr1=np.array(record.p_signal[:])
    x, y = arr1.T
    if record.sig_name[0]=='V4':
        x-=np.mean(x)
        scaledX=x.reshape(-1,1)
    else:
        y-=np.mean(y)
        scaledX=y.reshape(-1,1)
    return(scaledX)

# %%
# function to get r point
import numpy as np
def get_r_point_of_rec(scaledX):
    ts=[y for y in range(len(scaledX))]
    x=scaledX
    r_point_array = []
    start_index = 0
    while (start_index < len(scaledX)):
        if start_index == 0:
            ts=np.array([u+1 for u in range(200)])
            sample=x[:200]
            r_point_y=max(sample)
            point=np.where(sample == max(sample))[0][0]
            r_point_x=ts[point]
            #print(r_point_y)
            r_point_array+=[r_point_x]
            start_index=int(r_point_x)+40
        else:
            ts=np.array([u+1 for u in range(200)])

            sample=sample.reshape(1,-1)[0]
            next_i=0
            #print(sample)
            if (start_index+next_i)<len(scaledX):
                while (start_index+next_i)<len(scaledX) and (x[start_index+next_i]<0.24 or (x[next_i]<x[next_i+1])):
                    next_i+=1
                '''
                while (start_index+next_i)<record.sig_len and x[next_i]<x[next_i+1]:
                    next_i+=1
                '''
                r_point_array+=[start_index+next_i] 
            # next we find the slope made by the line connecting to the s point
            start_index=start_index+next_i+40
    return(r_point_array)

# %%
# function to get qrs angles
import math
def get_qrs_angles(scaledX,r_point_array):
    ts=[y for y in range(len(scaledX))]
    x=scaledX
    qrs_angle_list=[]
    for r_point_x in r_point_array:
        if r_point_x<len(scaledX):
            r_point_y=x[r_point_x]
            # next we find the slope made by the line connecting to the s point
            d=50
            if r_point_x+50>len(scaledX):
                d=len(scaledX)-r_point_x
            for j in range(r_point_x,r_point_x+d-1):
                if x[j]<x[j+1] and x[j]<0:
                    break
            for k in range(r_point_x,r_point_x-50,-1):
                if x[k-1]>x[k] and x[j]<0.5:
                    break
            q_point_y=x[k][0]
            q_point_x=k
            s_point_y=x[j][0]
            s_point_x=j
            #print(q_point_x,q_point_y,r_point_x,r_point_y,s_point_x,s_point_y)
            rs_slope=((s_point_y-r_point_y)/(s_point_x-r_point_x))
            qr_slope=((r_point_y-q_point_y)/(r_point_x-q_point_x))
            qrs_angle_list+=[180-(math.degrees(math.atan(qr_slope))+(180+(math.degrees(math.atan(rs_slope)))))]
    return(qrs_angle_list)

# %%
# function to get qrs area
def get_qrs_area(scaledX,r_point_array):
    ts=[y for y in range(len(scaledX))]
    x=scaledX
    qrs_area_list=[]
    for r_point_x in r_point_array:
        if r_point_x<len(scaledX):
            r_point_y=x[r_point_x][0]
            # next we find the slope made by the line connecting to the s point
            d=50
            if r_point_x+50>len(scaledX):
                d=len(scaledX)-r_point_x
            for j in range(r_point_x,r_point_x+d-1):
                if x[j]<x[j+1] and x[j]<0:
                    break
            for k in range(r_point_x,r_point_x-50,-1):
                if x[k-1]>x[k] and x[j]<0.5:
                    break
            q_point_y=x[k][0]
            q_point_x=k
            s_point_y=x[j][0]
            s_point_x=j
            #print(q_point_x,q_point_y,r_point_x,r_point_y,s_point_x,s_point_y)
            area_tri=0.5*((r_point_x*(q_point_y-s_point_y))+(q_point_x*(s_point_y-r_point_y))+(s_point_x*(r_point_y-q_point_y)))
            qrs_area_list+=[abs(area_tri)]
    return(qrs_area_list)

# %%
recordy=read_rec('european-st-t-database/e0103')
scaleddata=scale_input_data(recordy)
r_points=get_r_point_of_rec(scaleddata)
qrs_angles=get_qrs_angles(scaleddata,r_points)
qrs_areas=get_qrs_area(scaleddata,r_points)
print(np.nanmean(qrs_angles),np.nanstd(qrs_angles))
print(np.nanmean(qrs_areas),np.nanstd(qrs_areas))
# Out:
# e:\python\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# -3.8214620247519218 3.708720763557512
# 6.6019191484121516 4.309414502275011

# %%
print(r_points)
# Out:
# [51, 265, 497, 563, 749, 815, 998, 1252, 1317, 1495, 1557, 1754, 1818, 2014, 2260, 2324, 2499, 2565, 2740, 2802, 2980, 3042, 3220, 3282, 3465, 3530, 3716, 3954, 4012, 4190, 4250, 4434, 4499, 4674, 4739, 4921, 4986, 5178, 5244, 5440, 5700, 5953, 6208, 6274, 6471, 6727, 6987, 7256, 7321, 7518, 7585, 7777, 8030, 8096, 8295, 8361, 8567, 8633, 8835, 8901, 9088, 9157, 9353, 9417, 9623, 9687, 9885, 10138, 10392, 10645, 10705, 10897, 10957, 11150, 11217, 11409, 11667, 11733, 11931, 11994, 12186, 12246, 12450, 12516, 12718, 12987, 13249, 13520, 13782, 14040, 14106, 14286, 14546, 14614, 14810, 14876, 15078, 15347, 15596, 15660, 15838, 15903, 16095, 16160, 16356, 16419, 16623, 16689, 16881, 16949, 17141, 17206, 17398, 17463, 17656, 17721, 17908, 18161, 18414, 18667, 18920, 18984, 19164, 19408, 19474, 19656, 19720, 19912, 20165, 20227
        print("Mean of QRS angles:",np.nanmean(qrs_angles),";"+"Std deviation of QRS angle:",np.nanstd(qrs_angles))
        print("Mean of QRS area:",np.nanmean(qrs_areas),";"+"Std deviation of QRS area:",np.nanstd(qrs_areas))
# Out:
# Stats for european-st-t-database/e0103:
# ['V4', 'MLIII']
# e:\python\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# Mean of QRS angles: -3.8214620247519218 ;Std deviation of QRS angle: 3.708720763557512
# Mean of QRS area: 6.6019191484121516 ;Std deviation of QRS area: 4.309414502275011
# Stats for european-st-t-database/e0104:
# ['MLIII', 'V4']
# Mean of QRS angles: -6.362658145359661 ;Std deviation of QRS angle: 3.296319477194356
# Mean of QRS area: 5.435645319592504 ;Std deviation of QRS area: 3.557530911909112
# Stats for european-st-t-database/e0105:
# ['MLIII', 'V4']
# Mean of QRS angles: -5.95671707151073 ;Std deviation of QRS angle: 1.4485476744608534
# Mean of QRS area: 6.850037215411419 ;Std deviation of QRS area: 2.648464315783558
# Stats for european-st-t-database/e0106:
# ['MLIII', 'V3']
# Stats for european-st-t-database/e0107:
# ['D3', 'V4']
# Mean of QRS angles: -4.511132763107978 ;Std deviation of QRS angle: 3.430599257910867
# Mean of QRS area: 6.597078495709324 ;Std deviation of QRS area: 3.1242485736086385
# Stats for european-st-t-database/e0108:
# ['V4', 'MLIII']
# Mean of QRS angles: 0.01385358153387191 ;Std deviation of QRS angle: 2.104988759891956
# Mean of QRS area: 5.790986473358807 ;Std deviation of QRS area: 3.8509342007825675
# Stats for european-st-t-database/e0110:
# ['V3', 'MLIII']
# Stats for european-st-t-database/e0111:
# ['MLIII', 'V4']
# Mean of QRS angles: -2.262589581373058 ;Std deviation of QRS angle: 3.5935148727396786
# Mean of QRS area: 8.717769523034045 ;Std deviation of QRS area: 4.962878312066073
# Stats for european-st-t-database/e0112:
# ['MLIII', 'V4']
# Mean of QRS angles: -1.3219145678777184 ;Std deviation of QRS angle: 2.2257931680967986
# Mean of QRS area: 4.544728687072396 ;Std deviation of QRS area: 4.562581007278565
# Stats for european-st-t-database/e0113:
# ['MLIII', 'V4']
# Mean of QRS angles: 0.16329293869047867 ;Std deviation of QRS angle: 3.4241078152882074
# Mean of QRS area: 5.2669336640615505 ;Std deviation of QRS area: 3.1785996311324225
# Stats for european-st-t-database/e0114:
# ['MLIII', 'V4']
# Mean of QRS angles: -0.3813349333441628 ;Std deviation of QRS angle: 1.7909806370707044
# Mean of QRS area: 4.104149229464087 ;Std deviation of QRS area: 2.2266742656424823
# Stats for european-st-t-database/e0115:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0116:
# ['V4', 'MLIII']
# Mean of QRS angles: -1.3310656740218922 ;Std deviation of QRS angle: 1.1037222349569908
# Mean of QRS area: 5.865021642345134 ;Std deviation of QRS area: 5.494504633927248
# Stats for european-st-t-database/e0118:
# ['V4', 'MLIII']
# Mean of QRS angles: 0.7751260984050216 ;Std deviation of QRS angle: 2.280540692169208
# Mean of QRS area: 4.522746379033066 ;Std deviation of QRS area: 3.8814129090356246
# Stats for european-st-t-database/e0119:
# ['V4', 'MLIII']
# Mean of QRS angles: -0.053013965135065594 ;Std deviation of QRS angle: 1.93711718042064
# Mean of QRS area: 3.6947890000002426 ;Std deviation of QRS area: 5.516989341589046
# Stats for european-st-t-database/e0121:
# ['V4', 'MLIII']
# Mean of QRS angles: -0.9253328941065826 ;Std deviation of QRS angle: 2.247097140861733
# Mean of QRS area: 6.315392923029704 ;Std deviation of QRS area: 3.4736823655771802
# Stats for european-st-t-database/e0122:
# ['V4', 'MLIII']
# Mean of QRS angles: 1.2867288316919303 ;Std deviation of QRS angle: 3.484243196358208
# Mean of QRS area: 10.277592028721976 ;Std deviation of QRS area: 6.626154403454027
# Stats for european-st-t-database/e0123:
# ['V4', 'MLIII']
# Mean of QRS angles: 2.1448273975240473 ;Std deviation of QRS angle: 3.082368028234175
# Mean of QRS area: 7.195128482681652 ;Std deviation of QRS area: 3.2731634284382625
# Stats for european-st-t-database/e0124:
# ['V4', 'MLIII']
# Mean of QRS angles: 1.9219726532693278 ;Std deviation of QRS angle: 3.8874528331923486
# Mean of QRS area: 6.451935167422451 ;Std deviation of QRS area: 4.349659463641426
# Stats for european-st-t-database/e0125:
# ['V4', 'MLIII']
# Mean of QRS angles: 1.6570323304692132 ;Std deviation of QRS angle: 2.475361087504315
# Mean of QRS area: 5.889493809576785 ;Std deviation of QRS area: 2.4662257259343434
# Stats for european-st-t-database/e0126:
# ['V4', 'MLIII']
# Mean of QRS angles: 2.6026776944974532 ;Std deviation of QRS angle: 3.054194091024045
# Mean of QRS area: 6.677194501634014 ;Std deviation of QRS area: 3.1190841586800224
# Stats for european-st-t-database/e0127:
# ['V4', 'MLIII']
# Mean of QRS angles: -1.6437929686764134 ;Std deviation of QRS angle: 1.8954716245618912
# Mean of QRS area: 5.9465550834284455 ;Std deviation of QRS area: 3.0654289920039357
# Stats for european-st-t-database/e0129:
# ['MLIII', 'V3']
# Stats for european-st-t-database/e0133:
# ['MLIII', 'V3']
# Stats for european-st-t-database/e0136:
# ['MLIII', 'V4']
# Mean of QRS angles: -3.7951614891095558 ;Std deviation of QRS angle: 1.5429851962564276
# Mean of QRS area: 4.987828547764207 ;Std deviation of QRS area: 2.60583992921496
# Stats for european-st-t-database/e0139:
# ['MLIII', 'V4']
# Mean of QRS angles: -3.820572144963203 ;Std deviation of QRS angle: 2.168949506708991
# Mean of QRS area: 4.810029288524151 ;Std deviation of QRS area: 3.043593371475398
# Stats for european-st-t-database/e0147:
# ['MLIII', 'V4']
# Mean of QRS angles: 0.5030205683284139 ;Std deviation of QRS angle: 1.5272892657571706
# Mean of QRS area: 6.560802305444163 ;Std deviation of QRS area: 4.637717252941719
# Stats for european-st-t-database/e0148:
# ['MLIII', 'V4']
# Mean of QRS angles: -0.4696643478264757 ;Std deviation of QRS angle: 1.6308321809185498
# Mean of QRS area: 6.655403673470043 ;Std deviation of QRS area: 4.951136468623484
# Stats for european-st-t-database/e0151:
# ['V3', 'MLIII']
# Stats for european-st-t-database/e0154:
# ['MLIII', 'V4']
# Mean of QRS angles: 1.727107968398031 ;Std deviation of QRS angle: 2.84051746368416
# Mean of QRS area: 10.829439233428522 ;Std deviation of QRS area: 7.541615910492821
# Stats for european-st-t-database/e0155:
# ['MLIII', 'V4']
# Mean of QRS angles: 1.058314922866407 ;Std deviation of QRS angle: 2.709162958974893
# Mean of QRS area: 6.751861266353441 ;Std deviation of QRS area: 5.429666795197245
# Stats for european-st-t-database/e0159:
# ['MLIII', 'V4']
# Mean of QRS angles: 1.647860108466337 ;Std deviation of QRS angle: 3.32146338423267
# Mean of QRS area: 4.2182664088836805 ;Std deviation of QRS area: 2.351752932149406
# Stats for european-st-t-database/e0161:
# ['V4', 'MLIII']
# Mean of QRS angles: 3.5922867106906327 ;Std deviation of QRS angle: 3.4559200979817715
# Mean of QRS area: 7.326316342508236 ;Std deviation of QRS area: 3.3615337136957337
# Stats for european-st-t-database/e0162:
# ['MLIII', 'V4']
# Mean of QRS angles: -1.3778529632041228 ;Std deviation of QRS angle: 1.928419929769833
# Mean of QRS area: 8.28669158389966 ;Std deviation of QRS area: 5.75176162614508
# Stats for european-st-t-database/e0163:
# ['MLIII', 'V4']
# Mean of QRS angles: 0.232708258861236 ;Std deviation of QRS angle: 1.5907931368981088
# Mean of QRS area: 8.301713694507582 ;Std deviation of QRS area: 4.5553526394688255
# Stats for european-st-t-database/e0166:
# ['V4', 'MLIII']
# Mean of QRS angles: -3.1447128473144668 ;Std deviation of QRS angle: 4.013790798090458
# Mean of QRS area: 7.952356690328655 ;Std deviation of QRS area: 4.393657906377286
# Stats for european-st-t-database/e0170:
# ['V4', 'MLIII']
# Mean of QRS angles: -0.515112597247896 ;Std deviation of QRS angle: 2.7694711250787267
# Mean of QRS area: 9.320716660933279 ;Std deviation of QRS area: 5.992347766747083
# Stats for european-st-t-database/e0202:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0203:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0204:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0205:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0206:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0207:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0208:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0210:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0211:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0212:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0213:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0302:
# ['V3', 'V5']
# Stats for european-st-t-database/e0303:
# ['V2', 'V5']
# Stats for european-st-t-database/e0304:
# ['V3', 'V5']
# Stats for european-st-t-database/e0305:
# ['V2', 'V5']
# Stats for european-st-t-database/e0306:
# ['V2', 'V5']
# Stats for european-st-t-database/e0403:
# ['V5', 'V1']
# Stats for european-st-t-database/e0404:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0405:
# ['V5', 'V1']
# Stats for european-st-t-database/e0406:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0408:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0409:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0410:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0411:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0413:
# ['V2', 'V5']
# Stats for european-st-t-database/e0415:
# ['V2', 'V5']
# Stats for european-st-t-database/e0417:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0418:
# ['V5', 'MLI']
# Stats for european-st-t-database/e0501:
# ['V2', 'V4']
# Mean of QRS angles: 1.8103500722481567 ;Std deviation of QRS angle: 2.6300179084434854
# Mean of QRS area: 8.651817355943852 ;Std deviation of QRS area: 6.124718115877607
# Stats for european-st-t-database/e0509:
# ['V2', 'V4']
# Mean of QRS angles: -2.7284360030526114 ;Std deviation of QRS angle: 2.2596821952713624
# Mean of QRS area: 7.472540681692555 ;Std deviation of QRS area: 7.041731589354881
# Stats for european-st-t-database/e0515:
# ['V2', 'V5']
# Stats for european-st-t-database/e0601:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0602:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0603:
# ['V5', 'V2']
# Stats for european-st-t-database/e0604:
# ['V2', 'MLIII']
# Stats for european-st-t-database/e0605:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0606:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0607:
# ['V5', 'V4']
# Mean of QRS angles: 2.2015540211349687 ;Std deviation of QRS angle: 2.4688471441869533
# Mean of QRS area: 5.882412040162099 ;Std deviation of QRS area: 3.743915148377879
# Stats for european-st-t-database/e0609:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0610:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0611:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0612:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0613:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0614:
# ['V5', 'V1']
# Stats for european-st-t-database/e0615:
# ['V5', 'MLIII']
# Stats for european-st-t-database/e0704:
# ['V5', 'V1']
# Stats for european-st-t-database/e0801:
# ['V1', 'V5']
# Stats for european-st-t-database/e0808:
# ['V5', 'V1']
# Stats for european-st-t-database/e0817:
# ['V5', 'V1']
# Stats for european-st-t-database/e0818:
# ['V5', 'V1']
# Stats for european-st-t-database/e1301:
# ['V1', 'V5']
# Stats for european-st-t-database/e1302:
# ['V1', 'V5']
# Stats for european-st-t-database/e1304:
# ['V1', 'V5']

# %%
file_rec_list=rec_list('european-st-t-database')
for entry in file_rec_list:
    print("Stats for "+entry+":")
    recordy=read_rec(entry)
